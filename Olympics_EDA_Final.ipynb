# %% [markdown]
# # Olympics EDA Final
#
#
# *   Descriptive Analytics
# *   Data Visualizations
# *   Clean
#
#
#
#
# Jazmin Zamorano

# %% [markdown]
# ## File Merge

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics 01/Olympic EDA/Data/noc_regions.csv')

# %%
df.head(50)
# Out:
#     NOC                            region                 notes
# 0   AFG                       Afghanistan                   NaN
# 1   AHO                           Curacao  Netherlands Antilles
# 2   ALB                           Albania                   NaN
# 3   ALG                           Algeria                   NaN
# 4   AND                           Andorra                   NaN
# 5   ANG                            Angola                   NaN
# 6   ANT                           Antigua   Antigua and Barbuda
# 7   ANZ                         Australia           Australasia
# 8   ARG                         Argentina                   NaN
# 9   ARM                           Armenia                   NaN
# 10  ARU                             Aruba                   NaN
# 11  ASA                    American Samoa                   NaN
# 12  AUS                         Australia                   NaN
# 13  AUT                           Austria                   NaN
# ...

# %%
df.tail()
# Out:
#      NOC    region        notes
# 225  YEM     Yemen          NaN
# 226  YMD     Yemen  South Yemen
# 227  YUG    Serbia   Yugoslavia
# 228  ZAM    Zambia          NaN
# 229  ZIM  Zimbabwe          NaN

# %%
df.sample(10)
# Out:
#      NOC        region notes
# 50   CRO       Croatia   NaN
# 10   ARU         Aruba   NaN
# 162  POL        Poland   NaN
# 121  LTU     Lithuania   NaN
# 112  KUW        Kuwait   NaN
# 133  MKD     Macedonia   NaN
# 83   GUA     Guatemala   NaN
# 189  SUD         Sudan   NaN
# 180  SLE  Sierra Leone   NaN
# 3    ALG       Algeria   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#         NOC   region                 notes
# count   230      227                    21
# unique  230      206                    21
# top     AFG  Germany  Netherlands Antilles
# freq      1        4                     1

# %%
df.shape
# Out:
# (230, 3)

# %%
import pandas as pd

athlete_events = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics 01/Olympic EDA/Data/athlete_events.csv')
noc_regions = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics 01/Olympic EDA/Data/noc_regions.csv')

# %%
athlete_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
noc_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
athlete_events.shape
# Out:
# (271116, 15)

# %%
noc_regions.shape
# Out:
# (230, 3)

# %%
inner_merged = pd.merge(athlete_events, noc_regions, on='NOC', how='inner')
inner_merged.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
inner_merged.shape
# Out:
# (270767, 17)

# %%
inner_merged_total = pd.merge(athlete_events, noc_regions, on='NOC', how='inner')
inner_merged_total.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
outer_merged = pd.merge(athlete_events, noc_regions, on= 'NOC', how= 'outer')

# %%
left_merged = pd.merge(athlete_events, noc_regions, on= 'NOC', how= 'left')
left_merged.shape
# Out:
# (271116, 17)

# %%
left_merged_reversed = pd.merge(athlete_events, noc_regions, on= 'NOC', how= 'right')
left_merged_reversed.head()
# Out:
#        ID                   Name Sex   Age  Height  Weight         Team  NOC  \
# 0   502.0      Ahmad Shah Abouwi   M   NaN     NaN     NaN  Afghanistan  AFG
# 1  1076.0  Jammal-ud-Din Affendi   M  28.0     NaN     NaN  Afghanistan  AFG
# 2  1101.0   Mohammad Anwar Afzal   M   NaN     NaN     NaN  Afghanistan  AFG
# 3  1745.0         Mohammad Aktar   M  17.0   156.0    48.0  Afghanistan  AFG
# 4  4628.0  Mohammad Daoud Anwary   M  22.0     NaN     NaN  Afghanistan  AFG
#
#          Games    Year  Season       City      Sport  \
# 0  1956 Summer  1956.0  Summer  Melbourne     Hockey
# 1  1936 Summer  1936.0  Summer     Berlin     Hockey
# 2  1948 Summer  1948.0  Summer     London   Football
# 3  1980 Summer  1980.0  Summer     Moskva  Wrestling
# 4  1964 Summer  1964.0  Summer      Tokyo  Wrestling
#
#                                         Event Medal       region notes
# 0                         Hockey Men's Hockey   NaN  Afghanistan   NaN
# ...

# %%
right_merged = pd.merge(athlete_events, noc_regions, on= 'NOC', how= 'right')
right_merged.head()
# Out:
#        ID                   Name Sex   Age  Height  Weight         Team  NOC  \
# 0   502.0      Ahmad Shah Abouwi   M   NaN     NaN     NaN  Afghanistan  AFG
# 1  1076.0  Jammal-ud-Din Affendi   M  28.0     NaN     NaN  Afghanistan  AFG
# 2  1101.0   Mohammad Anwar Afzal   M   NaN     NaN     NaN  Afghanistan  AFG
# 3  1745.0         Mohammad Aktar   M  17.0   156.0    48.0  Afghanistan  AFG
# 4  4628.0  Mohammad Daoud Anwary   M  22.0     NaN     NaN  Afghanistan  AFG
#
#          Games    Year  Season       City      Sport  \
# 0  1956 Summer  1956.0  Summer  Melbourne     Hockey
# 1  1936 Summer  1936.0  Summer     Berlin     Hockey
# 2  1948 Summer  1948.0  Summer     London   Football
# 3  1980 Summer  1980.0  Summer     Moskva  Wrestling
# 4  1964 Summer  1964.0  Summer      Tokyo  Wrestling
#
#                                         Event Medal       region notes
# 0                         Hockey Men's Hockey   NaN  Afghanistan   NaN
# ...

# %%
athlete_events.join(noc_regions, lsuffix='_left', rsuffix='_right').head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#   NOC_left        Games  Year  Season       City          Sport  \
# 0      CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1      CHN  2012 Summer  2012  Summer     London           Judo
# 2      DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3      DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal NOC_right       region  \
# 0       Basketball Men's Basketball   NaN       AFG  Afghanistan
# ...

# %%
noc_regions.join(athlete_events, lsuffix='_left', rsuffix='_right').head()
# Out:
#   NOC_left       region                 notes  ID                      Name  \
# 0      AFG  Afghanistan                   NaN   1                 A Dijiang
# 1      AHO      Curacao  Netherlands Antilles   2                  A Lamusi
# 2      ALB      Albania                   NaN   3       Gunnar Nielsen Aaby
# 3      ALG      Algeria                   NaN   4      Edgar Lindenau Aabye
# 4      AND      Andorra                   NaN   5  Christine Jacoba Aaftink
#
#   Sex   Age  Height  Weight            Team NOC_right        Games  Year  \
# 0   M  24.0   180.0    80.0           China       CHN  1992 Summer  1992
# 1   M  23.0   170.0    60.0           China       CHN  2012 Summer  2012
# 2   M  24.0     NaN     NaN         Denmark       DEN  1920 Summer  1920
# 3   M  34.0     NaN     NaN  Denmark/Sweden       DEN  1900 Summer  1900
# 4   F  21.0   185.0    82.0     Netherlands       NED  1988 Winter  1988
#
# ...

# %%
inner_merged_total = pd.merge(athlete_events, noc_regions, on= 'NOC', how= 'inner')
inner_merged_total.head()

inner_joined_total = inner_merged_total.join(noc_regions, lsuffix='_left', rsuffix='_right').head()
inner_joined_total.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#   NOC_left        Games  Year  Season       City          Sport  \
# 0      CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1      CHN  2012 Summer  2012  Summer     London           Judo
# 2      DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3      DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  region_left notes_left NOC_right  \
# ...

# %%
noc_regions.join(athlete_events, lsuffix= "left").shape
# Out:
# (230, 18)

# %% [markdown]
# ### Visualization Graphs

# %%
print(df.columns)
# Out:
# Index(['NOC', 'region', 'notes'], dtype='object')

# %%
data = df['NOC'].value_counts()  # Counts occurrences of each unique value in 'Region'
data.plot.barh()  # Plots a horizontal bar chart
# Out:
# <Axes: ylabel='NOC'>

# %%
data = df['region'].value_counts()  # Counts occurrences of each unique value in 'Region'
data.plot.barh()  # Plots a horizontal bar chart
# Out:
# <Axes: ylabel='region'>

# %%
data = df['notes'].value_counts()  # Counts occurrences of each unique value in 'Region'
data.plot.barh()  # Plots a horizontal bar chart
# Out:
# <Axes: ylabel='notes'>

# %%
data = df['NOC'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['notes'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['region'].value_counts(ascending=True)
data.plot.barh();

# %%
data = df['NOC'].value_counts(normalize=True)
data
# Out:
# NOC
# AFG    0.004348
# NCA    0.004348
# NEP    0.004348
# NFL    0.004348
# NGR    0.004348
#          ...
# GHA    0.004348
# GRE    0.004348
# GRN    0.004348
# GUA    0.004348
# ZIM    0.004348
# Name: proportion, Length: 230, dtype: float64

# %%
data = df['notes'].value_counts(normalize=True)
data
# Out:
# notes
# Netherlands Antilles           0.047619
# Serbia and Montenegro          0.047619
# South Yemen                    0.047619
# North Yemen                    0.047619
# West Indies Federation         0.047619
# Unknown                        0.047619
# United Arab Republic           0.047619
# Tuvalu                         0.047619
# Trinidad and Tobago            0.047619
# Turks and Caicos Islands       0.047619
# Refugee Olympic Team           0.047619
# Antigua and Barbuda            0.047619
# Newfoundland                   0.047619
# North Borneo                   0.047619
# Virgin Islands                 0.047619
# Individual Olympic Athletes    0.047619
# Hong Kong                      0.047619
# Crete                          0.047619
# Bohemia                        0.047619
# Australasia                    0.047619
# Yugoslavia                     0.047619
# Name: proportion, dtype: float64

# %%
data = df['region'].value_counts(normalize=True)
data
# Out:
# region
# Germany           0.017621
# Yemen             0.013216
# Czech Republic    0.013216
# Serbia            0.013216
# Russia            0.013216
#                     ...
# Ghana             0.004405
# Grenada           0.004405
# Guatemala         0.004405
# Guinea            0.004405
# Zambia            0.004405
# Name: proportion, Length: 206, dtype: float64

# %%
data = df['NOC'].value_counts()
data
# Out:
# NOC
# AFG    1
# NCA    1
# NEP    1
# NFL    1
# NGR    1
#       ..
# GHA    1
# GRE    1
# GRN    1
# GUA    1
# ZIM    1
# Name: count, Length: 230, dtype: int64

# %%
data = df['region'].value_counts()
data
# Out:
# region
# Germany           4
# Yemen             3
# Czech Republic    3
# Serbia            3
# Russia            3
#                  ..
# Ghana             1
# Grenada           1
# Guatemala         1
# Guinea            1
# Zambia            1
# Name: count, Length: 206, dtype: int64

# %%
data = df['notes'].value_counts()
data
# Out:
# notes
# Netherlands Antilles           1
# Serbia and Montenegro          1
# South Yemen                    1
# North Yemen                    1
# West Indies Federation         1
# Unknown                        1
# United Arab Republic           1
# Tuvalu                         1
# Trinidad and Tobago            1
# Turks and Caicos Islands       1
# Refugee Olympic Team           1
# Antigua and Barbuda            1
# Newfoundland                   1
# North Borneo                   1
# Virgin Islands                 1
# Individual Olympic Athletes    1
# Hong Kong                      1
# Crete                          1
# Bohemia                        1
# Australasia                    1
# Yugoslavia                     1
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning Steps

# %%
run_times = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics 01/Olympic EDA/Data/noc_regions.csv')

# %%
run_times
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
run_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
run_times.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN
